# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/CS762/project/re-bench-data-contamination
# Out:
# /content/drive/MyDrive/CS762/project/re-bench-data-contamination

# %%
# !pip install -q torch>=2.0.0 transformers>=4.35.0 trl>=0.7.0 peft>=0.7.0 \
    accelerate>=0.24.0 datasets>=2.14.0 bitsandbytes>=0.41.0 \
    scipy tqdm pandas jinja2 pyyaml wandb evaluate

# %%
# !nvidia-smi
import torch
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"GPU: {torch.cuda.get_device_name(0)}")
print(f"Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
# Out:
# Thu Nov 20 05:45:30 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off |   00000000:00:05.0 Off |                    0 |
# | N/A   30C    P0             51W /  400W |       0MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
# !pip install -q wandb
import wandb
wandb.login()  # Enter your API key
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: vpapageorgiou to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# !python src/training/sft.py --config configs/train_config.yaml

# %%
from google.colab import runtime
runtime.unassign()
